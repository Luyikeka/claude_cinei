# %%
emis_integrator/
├── LICENSE
├── README.md
├── setup.py
├── emis_integrator/
│   ├── __init__.py
│   ├── core.py           # Main functions for emission integration
│   ├── utils.py          # Utility functions (like ll_area)
│   └── visualization.py  # Plotting and visualization tools
└── tests/
    ├── __init__.py
    ├── test_core.py
    └── test_utils.py
